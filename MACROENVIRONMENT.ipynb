# %% [markdown]
# <a href="https://colab.research.google.com/github/CaiqueBarrreto/agroci/blob/main/MACROENVIRONMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
#planilha de marcas

req = requests.get("https://www.motoo.com.br/emplacamentos/marcas-mais-vendidas/2022/")



content = req.content


soup = BeautifulSoup(content, 'html.parser')
table = soup.find_all(name='table')


table_str = str(table)

df = pd.read_html(table_str)[0]


df.to_excel('marcasmotos.xlsx',encoding='utf-8',index=False)

from google.colab import files

files.download('marcasmotos.xlsx')

# %%
#https://www.autoo.com.br/emplacamentos/veiculos-mais-vendidos/2022/

#planilha de veiculuos

req = requests.get("https://www.motoo.com.br/emplacamentos/motos-mais-vendidas/2022/")



content = req.content


soup = BeautifulSoup(content, 'html.parser')
table = soup.find_all(name='table')


table_str = str(table)

df = pd.read_html(table_str)[0]


df.to_excel('motos.xlsx',encoding='utf-8',index=False)

from google.colab import files

files.download('motos.xlsx')
